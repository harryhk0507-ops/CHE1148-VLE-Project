# %%
import pandas as pd
from itables import show

df1 = pd.read_csv("binary_5plus_high_mixture_count_part1.csv")
df2 = pd.read_csv("binary_5plus_high_mixture_count_part2.csv")
# Combine with df2 below df1
df = pd.concat([df1, df2], axis=0, ignore_index=True)

# %%
# Remove columns where ALL values are NaN/empty
df = df.dropna(axis=1, how="all")

# %%
print(df.shape)
show(df.iloc[1])
# Out:
# (1117058, 38)
# material_id                                                                                           1__2
# components                                                                         methane, carbon dioxide
# thermoml_fair_version                                                                               1.0.25
# property                                                                       Thermal conductivity, W/m/K
# value                                                                                              0.02125
# phase                                                                                                  Gas
# method                                                                                     Hot wire method
# source_file                                              C:\Users\harry\.thermoml\extracted_xml\10.1007...
# doi                                                                              10.1007/s10765-005-5566-6
# publication_year                                                                                      2005
# title                                                    Thermal Conductivity of Carbon Dioxide Methane...
# author                                                                                           Patek, J.
# journal                                                                                Int. J. Thermophys.
# Temperature, K                                                                                       300.0
# Pressure, kPa                                                                                       1288.0
# Mole fraction                                                                                       0.2493
# Molality, mol/kg                                                                                       NaN
# Mass density, kg/m3                                                                                    NaN
# Pressure, kPa_1                                                                                        NaN
# Pressure, kPa_2                                                                                        NaN
# Amount concentration (molarity), mol/dm3                                                               NaN
# Mass fraction                                                                                          NaN
# Mole fraction_2                                                                                        NaN
# Amount density, mol/m3                                                                                 NaN
# Mole fraction_1                                                                                        NaN
# Ratio of mass of solute to volume of solution, kg/m3                                                   NaN
# Frequency, MHz                                                                                         NaN
# Amount ratio of solute to solvent                                                                      NaN
# Wavelength, nm                                                                                         NaN
# Mass ratio of solute to solvent                                                                        NaN
# Volume fraction                                                                                        NaN
# Ratio of amount of solute to mass of solution, mol/kg                                                  NaN
# Initial molality of solute, mol/kg                                                                     NaN
# Final molality of solute, mol/kg                                                                       NaN
# Initial mass fraction of solute                                                                        NaN
# comp_list                                                                    ['methane', 'carbon dioxide']
# ncomp                                                                                                    2
# mix_key                                                                             carbon dioxide|methane
# Name: 1, dtype: object
# <!--| quarto-html-table-processing: none -->
# <table id="itables_5874493c_9f2c_4c95_9db2_c0a5326bc363"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.7.0 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_5874493c_9f2c_4c95_9db2_c0a5326bc363:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap", "compact"], "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>1</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"material_id\", \"1__2\"], [\"components\", \"methane, carbon dioxide\"], [\"thermoml_fair_version\", \"1.0.25\"], [\"property\", \"Thermal conductivity, W/m/K\"], [\"value\", \" 0.02125\"], [\"phase\", \"Gas\"], [\"method\", \"Hot wire method\"], [\"source_file\", \"C:\\\\Users\\\\harry\\\\.thermoml\\\\extracted_xml\\\\10.1007\\\\s10765-005-5566-6.xml\"], [\"doi\", \"10.1007/s10765-005-5566-6\"], [\"publication_year\", \"2005\"], [\"title\", \"Thermal Conductivity of Carbon Dioxide Methane Mixtures at Temperatures Between 300 and 425K and at Pressures up to 12 MPa\"], [\"author\", \"Patek, J.\"], [\"journal\", \"Int. J. Thermophys.\"], [\"Temperature, K\", \" 300.0\"], [\"Pressure, kPa\", \" 1288.0\"], [\"Mole fraction\", \" 0.2493\"], [\"Molality, mol/kg\", \"NaN\"], [\"Mass density, kg/m3\", \"NaN\"], [\"Pressure, kPa_1\", \"NaN\"], [\"Pressure, kPa_2\", \"NaN\"], [\"Amount concentration (molarity), mol/dm3\", \"NaN\"], [\"Mass fraction\", \"NaN\"], [\"Mole fraction_2\", \"NaN\"], [\"Amount density, mol/m3\", \"NaN\"], [\"Mole fraction_1\", \"NaN\"], [\"Ratio of mass of solute to volume of solution, kg/m3\", \"NaN\"], [\"Frequency, MHz\", \"NaN\"], [\"Amount ratio of solute to solvent\", \"NaN\"], [\"Wavelength, nm\", \"NaN\"], [\"Mass ratio of solute to solvent\", \"NaN\"], [\"Volume fraction\", \"NaN\"], [\"Ratio of amount of solute to mass of solution, mol/kg\", \"NaN\"], [\"Initial molality of solute, mol/kg\", \"NaN\"], [\"Final molality of solute, mol/kg\", \"NaN\"], [\"Initial mass fraction of solute\", \"NaN\"], [\"comp_list\", \"['methane', 'carbon dioxide']\"], [\"ncomp\", \"2\"], [\"mix_key\", \"carbon dioxide|methane\"]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %%
df_phase = df[df["phase"].isin(["Gas", "Liquid"])]
print(f"Shape after dropping: {df_phase.shape}")
# Out:
# Shape after dropping: (1055714, 38)

# %%
# Drop rows where Temperature,K is NaN
df_phase_T = df_phase.dropna(subset=["Temperature, K"], how="all")

print(f"Shape after dropping: {df_phase_T.shape}")
# Out:
# Shape after dropping: (929494, 38)

# %%
# Drop rows where ALL specified columns about Pressure (P) are NaN
df_phase_T_P = df_phase_T.dropna(subset=["Pressure, kPa"], how="all")

print(f"Shape after dropping: {df_phase_T_P.shape}")
# Out:
# Shape after dropping: (184803, 38)

# %%
# Remove columns where ALL values are NaN/empty
df_phase_T_P_columns = df_phase_T_P.dropna(axis=1, how="all")

print(f"Shape after dropping: {df_phase_T_P_columns.shape}")
print(df_phase_T_P_columns.columns.tolist())
# Out:
# Shape after dropping: (184803, 28)
# ['material_id', 'components', 'thermoml_fair_version', 'property', 'value', 'phase', 'method', 'source_file', 'doi', 'publication_year', 'title', 'author', 'journal', 'Temperature, K', 'Pressure, kPa', 'Mole fraction', 'Molality, mol/kg', 'Amount concentration (molarity), mol/dm3', 'Mass fraction', 'Frequency, MHz', 'Amount ratio of solute to solvent', 'Mass ratio of solute to solvent', 'Volume fraction', 'Initial molality of solute, mol/kg', 'Final molality of solute, mol/kg', 'comp_list', 'ncomp', 'mix_key']

# %%
# Drop rows where ALL specified columns about mole fractions are NaN
df_phase_T_P_columns.loc[
    df_phase_T_P_columns["property"] == "mole fraction",
    "Mole fraction"
] = df_phase_T_P_columns["value"]
df_phase_T_P_mf = df_phase_T_P_columns.dropna(subset=["Mole fraction"], how="all")

print(f"Shape after dropping: {df_phase_T_P_mf.shape}")
# Out:
# Shape after dropping: (110383, 28)

# %%
# Replace 'Column1', 'Column2', etc. with the actual names of the columns you want to keep
df_clean = df_phase_T_P_mf[[
    "property",
    "value",
    "phase",
    "Temperature, K",
    "Pressure, kPa",
    "Mole fraction",
    "mix_key"
]]

# %%
show(df_clean.head())
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_27eff571_d20e_44b2_ba10_90cde1da4e6e"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.7.0 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_27eff571_d20e_44b2_ba10_90cde1da4e6e:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap", "compact"], "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>property</th>\n      <th>value</th>\n      <th>phase</th>\n      <th>Temperature, K</th>\n      <th>Pressure, kPa</th>\n      <th>Mole fraction</th>\n      <th>mix_key</th>\n    </tr>\n  </thead></table>", "data_json": "[[0, \"Thermal conductivity, W/m/K\", [\"0.02096\", 1], \"Gas\", [\"300.0\", 1], [\"724.0\", 1], [\"0.2493\", 1], \"carbon dioxide|methane\"], [1, \"Thermal conductivity, W/m/K\", [\"0.02125\", 2], \"Gas\", [\"300.0\", 1], [\"1288.0\", 2], [\"0.2493\", 1], \"carbon dioxide|methane\"], [2, \"Thermal conductivity, W/m/K\", [\"0.02161\", 3], \"Gas\", [\"300.0\", 1], [\"1835.0\", 3], [\"0.2493\", 1], \"carbon dioxide|methane\"], [3, \"Thermal conductivity, W/m/K\", [\"0.02197\", 4], \"Gas\", [\"300.0\", 1], [\"2335.0\", 4], [\"0.2493\", 1], \"carbon dioxide|methane\"], [4, \"Thermal conductivity, W/m/K\", [\"0.02245\", 5], \"Gas\", [\"300.0\", 1], [\"2820.0\", 5], [\"0.2493\", 1], \"carbon dioxide|methane\"]]", "columnDefs": [{"targets": [2, 4, 5, 6], "render": "\n                        function (data, type, row, meta) {\n                            return type === 'sort' ? data[1] : data[0];\n                        }\n                    "}], "keys_to_be_evaluated": [["columnDefs", 0, "render"]]};
#         new ITable(table, dt_args);
#     });
# </script>

# %%
df_clean[["Component 1", "Component 2"]] = (
    df_clean["mix_key"]
    .str.split("|", expand=True, regex=False)
)
df_clean.drop(columns=["mix_key"], inplace=True)
show(df_clean.head())
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_51780b41_80ee_4c3c_a9f2_494724be0126"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.7.0 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.5.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.5.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_51780b41_80ee_4c3c_a9f2_494724be0126:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "text_in_header_can_be_selected": true, "classes": ["display", "nowrap", "compact"], "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      <th></th>\n      <th>property</th>\n      <th>value</th>\n      <th>phase</th>\n      <th>Temperature, K</th>\n      <th>Pressure, kPa</th>\n      <th>Mole fraction</th>\n      <th>Component 1</th>\n      <th>Component 2</th>\n    </tr>\n  </thead></table>", "data_json": "[[0, \"Thermal conductivity, W/m/K\", [\"0.02096\", 1], \"Gas\", [\"300.0\", 1], [\"724.0\", 1], [\"0.2493\", 1], \"carbon dioxide\", \"methane\"], [1, \"Thermal conductivity, W/m/K\", [\"0.02125\", 2], \"Gas\", [\"300.0\", 1], [\"1288.0\", 2], [\"0.2493\", 1], \"carbon dioxide\", \"methane\"], [2, \"Thermal conductivity, W/m/K\", [\"0.02161\", 3], \"Gas\", [\"300.0\", 1], [\"1835.0\", 3], [\"0.2493\", 1], \"carbon dioxide\", \"methane\"], [3, \"Thermal conductivity, W/m/K\", [\"0.02197\", 4], \"Gas\", [\"300.0\", 1], [\"2335.0\", 4], [\"0.2493\", 1], \"carbon dioxide\", \"methane\"], [4, \"Thermal conductivity, W/m/K\", [\"0.02245\", 5], \"Gas\", [\"300.0\", 1], [\"2820.0\", 5], [\"0.2493\", 1], \"carbon dioxide\", \"methane\"]]", "columnDefs": [{"targets": [2, 4, 5, 6], "render": "\n                        function (data, type, row, meta) {\n                            return type === 'sort' ? data[1] : data[0];\n                        }\n                    "}], "keys_to_be_evaluated": [["columnDefs", 0, "render"]]};
#         new ITable(table, dt_args);
#     });
# </script>

# %%
df_clean.to_csv("Cleaned_VLE_Data.csv", index=False)
